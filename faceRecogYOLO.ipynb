# %%
import cv2
import ultralytics
import random
import os

import torch
import numpy as np
from facenet_pytorch import InceptionResnetV1
from PIL import Image

from scipy.spatial.distance import cosine

from ultralytics import YOLO
# ultralytics.checks()

# Load the YOLOv8-face model
model = YOLO(r"D:\FCR\FaceRecognition\yolov11n-face.pt")  # yolov11n-face is a pre-trained small model for face detection

# %%
# Load known face embeddings and labels
known_embeddings = np.load("known_face_embeddings.npy")
known_labels = np.load("known_labels.npy")

# Initialize Facenet model for generating embeddings
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
face_recognition_model = InceptionResnetV1(pretrained='vggface2').eval().to(device)

# %% [markdown]
# ### Generate Face Embeddings for each person

# %%
# Constants
THRESHOLD = 0.5
MIN_FACE_SIZE = 32
TARGET_SIZE = (640, 640)

# %%
# Base directory containing folders of images for each person
base_dir = r"D:\FCR\FaceRecognition\Dataset"

# Lists to hold embeddings and labels
embeddings = []
labels = []

def preprocess_image(img):
    """Consistent image preprocessing"""
    if isinstance(img, np.ndarray):
        img = Image.fromarray(img)
    img = img.convert('RGB').resize((160, 160))
    img_tensor = torch.tensor(np.array(img)).permute(2, 0, 1).unsqueeze(0).float()
    img_tensor = (img_tensor - 127.5) / 128.0
    return img_tensor.to(device)

def get_embedding(img):
    """Generate normalized embedding for an image"""
    img_tensor = preprocess_image(img)
    with torch.no_grad():
        embedding = face_recognition_model(img_tensor).cpu().numpy().flatten()
        embedding = embedding / np.linalg.norm(embedding)  # L2 normalize
    return embedding

def find_closest_match(embedding, known_embeddings, known_labels, threshold=THRESHOLD):
    """Find the closest matching face using cosine similarity"""
    if len(known_embeddings) == 0:
        return "Unknown", 0.0
    
    # Calculate similarities
    similarities = [1 - cosine(embedding, known_emb) for known_emb in known_embeddings]
    max_similarity = max(similarities)
    max_index = np.argmax(similarities)
    
    # Debug print
    print(f"Max similarity: {max_similarity:.3f}, Threshold: {threshold}")
    print(f"Similarities: {list(zip(known_labels, similarities))}")
    
    # Stricter threshold check
    if max_similarity > threshold:
        return known_labels[max_index], max_similarity
    else:
        return "Unknown", max_similarity

# %%
# # Training phase: Generate embeddings for known faces
# print("Starting training phase...")
# for person_name in os.listdir(base_dir):
#     person_dir = os.path.join(base_dir, person_name)
#     if os.path.isdir(person_dir):
#         person_embeddings = []
#         print(f"Processing images for {person_name}...")

#         for image_name in os.listdir(person_dir):
#             image_path = os.path.join(person_dir, image_name)
#             try:
#                 img = Image.open(image_path)
#                 embedding = get_embedding(img)
#                 person_embeddings.append(embedding)
#             except Exception as e:
#                 print(f"Error processing {image_path}: {e}")

#         if person_embeddings:
#             mean_embedding = np.mean(person_embeddings, axis=0)
#             mean_embedding = mean_embedding / np.linalg.norm(mean_embedding)  # L2 normalize
#             embeddings.append(mean_embedding)
#             labels.append(person_name)

# # Save embeddings and labels
# np.save("known_face_embeddings.npy", embeddings)
# np.save("known_labels.npy", labels)
# print("Training phase completed. Embeddings saved.")

# %%
# Load known face embeddings and labels
known_embeddings = np.load("known_face_embeddings.npy")
known_labels = np.load("known_labels.npy")

# Real-time recognition phase
print("Starting real-time recognition...")
cap = cv2.VideoCapture(r"C:\Users\arauf\Pictures\Camera Roll\test_vid.mp4")

if not cap.isOpened():
    print("Error: Could not open video stream.")
    exit()

while True:
    try:
        ret, frame = cap.read()
        if not ret:
            print("Error: Failed to capture image.")
            break

        results = model(frame)

        for result in results:
            boxes = result.boxes

            for box in boxes:
                x1, y1, x2, y2 = box.xyxy[0].cpu().numpy().astype(int)
                confidence = box.conf[0].cpu().numpy()

                face = frame[y1:y2, x1:x2]
                
                if face.shape[0] < MIN_FACE_SIZE or face.shape[1] < MIN_FACE_SIZE:
                    face = cv2.resize(face, (MIN_FACE_SIZE, MIN_FACE_SIZE))

                embedding = get_embedding(face)
                label, similarity = find_closest_match(embedding, known_embeddings, known_labels)

                # Draw bounding box and label with both detection and recognition confidence
                cv2.rectangle(frame, (x1, y1), (x2, y2), (255, 0, 0), 2)
                cv2.putText(frame, 
                           f"{label} (D:{confidence:.2f} R:{similarity:.2f})", 
                           (x1, y1 - 10), 
                           cv2.FONT_HERSHEY_SIMPLEX, 
                           0.6, 
                           (255, 0, 0), 
                           2)

        cv2.imshow("Face Detection & Recognition", frame)

    except Exception as e:
        print(f"Error in main loop: {e}")

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# Starting real-time recognition...
#
# 0: 480x640 3 faces, 124.5ms
# Speed: 0.0ms preprocess, 124.5ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# Max similarity: 0.804, Threshold: 0.5
# Similarities: [('Abdul', 0.20121999375701027), ('Adeen', 0.8042129990927592), ('Fazal', 0.4177745927706611)]
# Max similarity: 0.498, Threshold: 0.5
# Similarities: [('Abdul', 0.2611704468727112), ('Adeen', 0.333141565322876), ('Fazal', 0.49769172072410583)]
# Max similarity: 0.277, Threshold: 0.5
# Similarities: [('Abdul', -0.1569363921880722), ('Adeen', 0.27654850482940674), ('Fazal', 0.10512511432170868)]
#
# 0: 480x640 3 faces, 1.3ms
# Speed: 2.0ms preprocess, 1.3ms inference, 14.1ms postprocess per image at shape (1, 3, 480, 640)
# Max similarity: 0.808, Threshold: 0.5
# Similarities: [('Abdul', 0.20687712986009577), ('Adeen', 0.8075610513948782), ('Fazal', 0.42226073609228587)]
# Max similarity: 0.271, Threshold: 0.5
# Similarities: [('Abdul', 0.153857221969532), ('Adeen', 0.27110414081191225), ('Fazal', 0.21222441123578517)]
# Max similarity: 0.244, Threshold: 0.5
# Similarities: [('Abdul', -0.21085582673549652), ('Adeen', 0.24410158395767212), ('Fazal', 0.11521493643522263)]
#
# 0: 480x640 3 faces, 1.0ms
# Speed: 1.7ms preprocess, 1.0ms inference, 15.1ms postprocess per image at shape (1, 3, 480, 640)
# Max similarity: 0.815, Threshold: 0.5
# Similarities: [('Abdul', 0.24653266370296478), ('Adeen', 0.8147170543670654), ('Fazal', 0.43593665957450867)]
# Max similarity: 0.233, Threshold: 0.5
# Similarities: [('Abdul', 0.18009237945079803), ('Adeen', 0.17711375653743744), ('Fazal', 0.23318728804588318)]
# Max similarity: 0.261, Threshold: 0.5
# Similarities: [('Abdul', -0.12203267216682434), ('Adeen', 0.2611258625984192), ('Fazal', 0.136322483420372)]
#
# 0: 480x640 3 faces, 0.0ms
# Speed: 1.3ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Max similarity: 0.814, Threshold: 0.5
# Similarities: [('Abdul', 0.2109314501285553), ('Adeen', 0.8142924904823303), ('Fazal', 0.436917781829834)]
# Max similarity: 0.278, Threshold: 0.5
# Similarities: [('Abdul', 0.14054591953754425), ('Adeen', 0.2783927321434021), ('Fazal', 0.20885862410068512)]
# Max similarity: 0.213, Threshold: 0.5
# Similarities: [('Abdul', -0.2265420421038844), ('Adeen', 0.21339129129700152), ('Fazal', 0.10047706362741826)]
#
# 0: 480x640 3 faces, 0.0ms
# Speed: 1.0ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Max similarity: 0.812, Threshold: 0.5
# Similarities: [('Abdul', 0.18930922810380324), ('Adeen', 0.811649154922418), ('Fazal', 0.4475135834507007)]
# Max similarity: 0.402, Threshold: 0.5
# Similarities: [('Abdul', 0.18964430689811707), ('Adeen', 0.2732369005680084), ('Fazal', 0.40186041593551636)]
# Max similarity: 0.239, Threshold: 0.5
# Similarities: [('Abdul', -0.18425439298152924), ('Adeen', 0.23886695504188538), ('Fazal', 0.12578442692756653)]
#
# 0: 480x640 3 faces, 12.9ms
# Speed: 1.0ms preprocess, 12.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Max similarity: 0.820, Threshold: 0.5
# Similarities: [('Abdul', 0.17054533958435059), ('Adeen', 0.8201002478599548), ('Fazal', 0.39005017280578613)]
# Max similarity: 0.350, Threshold: 0.5
# Similarities: [('Abdul', 0.13972216844558716), ('Adeen', 0.20174935460090637), ('Fazal', 0.34963876008987427)]
# Max similarity: 0.236, Threshold: 0.5
# Similarities: [('Abdul', -0.15735182166099548), ('Adeen', 0.23586158454418182), ('Fazal', 0.13433977961540222)]
#
# 0: 480x640 3 faces, 19.9ms
# Speed: 1.0ms preprocess, 19.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Max similarity: 0.808, Threshold: 0.5
# Similarities: [('Abdul', 0.16535243391990662), ('Adeen', 0.8084347248077393), ('Fazal', 0.3890860080718994)]
# Max similarity: 0.384, Threshold: 0.5
# Similarities: [('Abdul', 0.13584032654762268), ('Adeen', 0.22838541865348816), ('Fazal', 0.3838613033294678)]
# Max similarity: 0.229, Threshold: 0.5
# Similarities: [('Abdul', -0.15101094543933868), ('Adeen', 0.22912339866161346), ('Fazal', 0.13214027881622314)]
#
# 0: 480x640 3 faces, 11.9ms
# Speed: 1.8ms preprocess, 11.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Max similarity: 0.817, Threshold: 0.5
# Similarities: [('Abdul', 0.1669617344759864), ('Adeen', 0.8165620078705559), ('Fazal', 0.3821156393220646)]
# Max similarity: 0.203, Threshold: 0.5
# Similarities: [('Abdul', -0.01335330680012703), ('Adeen', 0.20260173082351685), ('Fazal', 0.18287226557731628)]
# Max similarity: 0.194, Threshold: 0.5
# Similarities: [('Abdul', -0.21124115586280823), ('Adeen', 0.1941428780555725), ('Fazal', 0.13616329431533813)]
#
# 0: 480x640 3 faces, 0.0ms
# Speed: 0.6ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Max similarity: 0.818, Threshold: 0.5
# Similarities: [('Abdul', 0.1611676663160324), ('Adeen', 0.8180750012397766), ('Fazal', 0.39373576641082764)]
# Max similarity: 0.178, Threshold: 0.5
# Similarities: [('Abdul', -0.062111616134643555), ('Adeen', 0.17814113199710846), ('Fazal', 0.13464237749576569)]
# Max similarity: 0.257, Threshold: 0.5
# Similarities: [('Abdul', -0.17207713889615928), ('Adeen', 0.25705625074766614), ('Fazal', 0.13188072252984528)]
#
# 0: 480x640 3 faces, 12.8ms
# Speed: 1.3ms preprocess, 12.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Max similarity: 0.810, Threshold: 0.5
# Similarities: [('Abdul', 0.15613125264644623), ('Adeen', 0.8100038766860962), ('Fazal', 0.38574719429016113)]
# Max similarity: 0.307, Threshold: 0.5
# Similarities: [('Abdul', 0.06430321931838989), ('Adeen', 0.21957534551620483), ('Fazal', 0.3071479797363281)]
# Max similarity: 0.243, Threshold: 0.5
# Similarities: [('Abdul', -0.1926555335521698), ('Adeen', 0.24265116453170776), ('Fazal', 0.17108842730522156)]
#
# 0: 480x640 3 faces, 11.9ms
# Speed: 2.1ms preprocess, 11.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Max similarity: 0.821, Threshold: 0.5
# Similarities: [('Abdul', 0.1701277494430542), ('Adeen', 0.8210105895996094), ('Fazal', 0.4029226005077362)]
# Max similarity: 0.318, Threshold: 0.5
# Similarities: [('Abdul', 0.02971223182976246), ('Adeen', 0.2273474931716919), ('Fazal', 0.3184468150138855)]
# Max similarity: 0.203, Threshold: 0.5
# Similarities: [('Abdul', -0.1971010597287981), ('Adeen', 0.19828617881022859), ('Fazal', 0.20282592160547286)]
#
# 0: 480x640 3 faces, 24.0ms
# Speed: 0.0ms preprocess, 24.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Max similarity: 0.826, Threshold: 0.5
# Similarities: [('Abdul', 0.16302870213985443), ('Adeen', 0.8258465528488159), ('Fazal', 0.38319435715675354)]
# Max similarity: 0.354, Threshold: 0.5
# Similarities: [('Abdul', 0.019634402118062888), ('Adeen', 0.17614184760201912), ('Fazal', 0.35405842339644356)]
# Max similarity: 0.195, Threshold: 0.5
# Similarities: [('Abdul', -0.1813405346071404), ('Adeen', 0.187844593057359), ('Fazal', 0.1950349095442948)]
#
# 0: 480x640 3 faces, 11.9ms
# Speed: 1.0ms preprocess, 11.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Max similarity: 0.818, Threshold: 0.5
# Similarities: [('Abdul', 0.1532022265671359), ('Adeen', 0.8175618161224251), ('Fazal', 0.366098054283974)]
# Max similarity: 0.355, Threshold: 0.5
# Similarities: [('Abdul', 0.07540184259414673), ('Adeen', 0.26557913422584534), ('Fazal', 0.3548438549041748)]
# Max similarity: 0.226, Threshold: 0.5
# Similarities: [('Abdul', -0.198233962059021), ('Adeen', 0.22551116347312927), ('Fazal', 0.19526158273220062)]
#
# 0: 480x640 3 faces, 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Max similarity: 0.833, Threshold: 0.5
# Similarities: [('Abdul', 0.15801051807340905), ('Adeen', 0.8329435090456316), ('Fazal', 0.3669227739022516)]
# Max similarity: 0.300, Threshold: 0.5
# Similarities: [('Abdul', 0.06648163101186577), ('Adeen', 0.21305601519012396), ('Fazal', 0.2995914042239549)]
# Max similarity: 0.200, Threshold: 0.5
# Similarities: [('Abdul', -0.15552063286304474), ('Adeen', 0.20010289549827576), ('Fazal', 0.17038613557815552)]
#
# 0: 480x640 3 faces, 11.7ms
# Speed: 1.0ms preprocess, 11.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Max similarity: 0.816, Threshold: 0.5
# Similarities: [('Abdul', 0.12253891691333574), ('Adeen', 0.8156802168083076), ('Fazal', 0.3925757174148735)]
# Max similarity: 0.233, Threshold: 0.5
# Similarities: [('Abdul', -0.028248656541109085), ('Adeen', 0.19517332315444946), ('Fazal', 0.23305991291999817)]
# Max similarity: 0.219, Threshold: 0.5
# Similarities: [('Abdul', -0.08693113923072815), ('Adeen', 0.2191617786884308), ('Fazal', 0.17594259977340698)]
#
# 0: 480x640 3 faces, 14.3ms
# Speed: 0.0ms preprocess, 14.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Max similarity: 0.830, Threshold: 0.5
# Similarities: [('Abdul', 0.1263323426246643), ('Adeen', 0.8298437595367432), ('Fazal', 0.3805828094482422)]
# Max similarity: 0.245, Threshold: 0.5
# Similarities: [('Abdul', 0.03536071417565867), ('Adeen', 0.2445051822361246), ('Fazal', 0.23980514765947225)]
# Max similarity: 0.208, Threshold: 0.5
# Similarities: [('Abdul', -0.07994521677820599), ('Adeen', 0.2079498941928215), ('Fazal', 0.19777120961122496)]
#
# 0: 480x640 3 faces, 4.8ms
# Speed: 2.1ms preprocess, 4.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Max similarity: 0.841, Threshold: 0.5
# Similarities: [('Abdul', 0.15473320157926107), ('Adeen', 0.8411244248673677), ('Fazal', 0.3837113747768781)]
# Max similarity: 0.218, Threshold: 0.5
# Similarities: [('Abdul', 0.013616859912872314), ('Adeen', 0.21095526218414307), ('Fazal', 0.21755307912826538)]
# Max similarity: 0.212, Threshold: 0.5
# Similarities: [('Abdul', -0.17002250730857238), ('Adeen', 0.21181595553064647), ('Fazal', 0.1736121670238875)]
#
# 0: 480x640 3 faces, 10.9ms
# Speed: 2.0ms preprocess, 10.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Max similarity: 0.835, Threshold: 0.5
# Similarities: [('Abdul', 0.1607549488544464), ('Adeen', 0.8345064520835876), ('Fazal', 0.3601292669773102)]
# Max similarity: 0.263, Threshold: 0.5
# Similarities: [('Abdul', -0.0015913806855678558), ('Adeen', 0.18476378917694092), ('Fazal', 0.26274359226226807)]
# Max similarity: 0.234, Threshold: 0.5
# Similarities: [('Abdul', -0.15285617113113403), ('Adeen', 0.23379212617874146), ('Fazal', 0.19075816869735718)]
#
# 0: 480x640 3 faces, 5.3ms
# Speed: 1.0ms preprocess, 5.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Max similarity: 0.840, Threshold: 0.5
# Similarities: [('Abdul', 0.1582603007555008), ('Adeen', 0.8402496576309204), ('Fazal', 0.3551633358001709)]
# Max similarity: 0.336, Threshold: 0.5
# Similarities: [('Abdul', 0.09285899996757507), ('Adeen', 0.22707206010818481), ('Fazal', 0.33577877283096313)]
# Max similarity: 0.217, Threshold: 0.5
# Similarities: [('Abdul', -0.12018480896949768), ('Adeen', 0.21725499629974365), ('Fazal', 0.1127578392624855)]
#
# 0: 480x640 3 faces, 5.2ms
# Speed: 1.1ms preprocess, 5.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Max similarity: 0.835, Threshold: 0.5
# Similarities: [('Abdul', 0.18086892366409302), ('Adeen', 0.8346042037010193), ('Fazal', 0.37293940782546997)]
# Max similarity: 0.446, Threshold: 0.5
# Similarities: [('Abdul', 0.2282428605411736), ('Adeen', 0.3728467897864116), ('Fazal', 0.44558474745841425)]
# Max similarity: 0.188, Threshold: 0.5
# Similarities: [('Abdul', -0.1289321482181549), ('Adeen', 0.18784797191619873), ('Fazal', 0.06203141435980797)]
#
# 0: 480x640 3 faces, 14.1ms
# Speed: 0.0ms preprocess, 14.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Max similarity: 0.840, Threshold: 0.5
# Similarities: [('Abdul', 0.18226740167931343), ('Adeen', 0.8396491503924652), ('Fazal', 0.3712328451137046)]
# Max similarity: 0.345, Threshold: 0.5
# Similarities: [('Abdul', -0.06330573558807373), ('Adeen', 0.1944746971130371), ('Fazal', 0.34481000900268555)]
# Max similarity: 0.224, Threshold: 0.5
# Similarities: [('Abdul', -0.12154246142253533), ('Adeen', 0.22415001844465665), ('Fazal', 0.07315968286039354)]
#
# 0: 480x640 3 faces, 9.4ms
# Speed: 1.5ms preprocess, 9.4ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# Max similarity: 0.853, Threshold: 0.5
# Similarities: [('Abdul', 0.2021169364452362), ('Adeen', 0.8532876372337341), ('Fazal', 0.3603264093399048)]
# Max similarity: 0.364, Threshold: 0.5
# Similarities: [('Abdul', -0.03537692129611969), ('Adeen', 0.26545852422714233), ('Fazal', 0.36405545473098755)]
# Max similarity: 0.214, Threshold: 0.5
# Similarities: [('Abdul', -0.17164522409439087), ('Adeen', 0.2075509876012802), ('Fazal', 0.21419045329093933)]
#
# 0: 480x640 3 faces, 11.9ms
# Speed: 1.0ms preprocess, 11.9ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
# Max similarity: 0.856, Threshold: 0.5
# Similarities: [('Abdul', 0.19660549184051246), ('Adeen', 0.8561512913613757), ('Fazal', 0.361073025401055)]
# Max similarity: 0.402, Threshold: 0.5
# Similarities: [('Abdul', 0.027479445561766624), ('Adeen', 0.3337414264678955), ('Fazal', 0.4023715853691101)]
# Max similarity: 0.210, Threshold: 0.5
# Similarities: [('Abdul', -0.1625092379743318), ('Adeen', 0.20961511375814035), ('Fazal', 0.20827719817893553)]
#
# 0: 480x640 3 faces, 6.2ms
# Speed: 2.1ms preprocess, 6.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Max similarity: 0.846, Threshold: 0.5
# Similarities: [('Abdul', 0.18278812272619505), ('Adeen', 0.8463290425342908), ('Fazal', 0.36773774816168925)]
# Max similarity: 0.417, Threshold: 0.5
# Similarities: [('Abdul', 0.07701053470373154), ('Adeen', 0.3557375371456146), ('Fazal', 0.41690903902053833)]
# Max similarity: 0.212, Threshold: 0.5
# Similarities: [('Abdul', -0.12388978160084618), ('Adeen', 0.21182464290710468), ('Fazal', 0.17382945574346476)]
#
# 0: 480x640 3 faces, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Max similarity: 0.854, Threshold: 0.5
# Similarities: [('Abdul', 0.14663097262382507), ('Adeen', 0.8539280295372009), ('Fazal', 0.3400382101535797)]
# Max similarity: 0.482, Threshold: 0.5
# Similarities: [('Abdul', 0.10045555526548033), ('Adeen', 0.3840158421974398), ('Fazal', 0.4818068764440002)]
# Max similarity: 0.197, Threshold: 0.5
# Similarities: [('Abdul', -0.12531016020118257), ('Adeen', 0.19736431852791836), ('Fazal', 0.18926121656529837)]
#
# 0: 480x640 3 faces, 6.9ms
# Speed: 2.3ms preprocess, 6.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Max similarity: 0.855, Threshold: 0.5
# Similarities: [('Abdul', 0.16806116700172424), ('Adeen', 0.8546415567398071), ('Fazal', 0.331329345703125)]
# Max similarity: 0.446, Threshold: 0.5
# Similarities: [('Abdul', 0.07581357657909393), ('Adeen', 0.3579298257827759), ('Fazal', 0.44626379013061523)]
# Max similarity: 0.238, Threshold: 0.5
# Similarities: [('Abdul', -0.16715477900774633), ('Adeen', 0.22665174444605485), ('Fazal', 0.23794403744077508)]
#
# 0: 480x640 3 faces, 13.4ms
# Speed: 0.0ms preprocess, 13.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Max similarity: 0.853, Threshold: 0.5
# Similarities: [('Abdul', 0.16272220535742044), ('Adeen', 0.853259154959969), ('Fazal', 0.3049617525957975)]
# Max similarity: 0.419, Threshold: 0.5
# Similarities: [('Abdul', 0.1148652738413054), ('Adeen', 0.40106222623215837), ('Fazal', 0.4191182303954233)]
# Max similarity: 0.206, Threshold: 0.5
# Similarities: [('Abdul', -0.16183620691299438), ('Adeen', 0.18779531121253967), ('Fazal', 0.2062293440103531)]
#
# 0: 480x640 3 faces, 11.7ms
# Speed: 1.4ms preprocess, 11.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Max similarity: 0.838, Threshold: 0.5
# Similarities: [('Abdul', 0.15483641624450684), ('Adeen', 0.8375251293182373), ('Fazal', 0.308449923992157)]
# Max similarity: 0.334, Threshold: 0.5
# Similarities: [('Abdul', 0.08599227154300992), ('Adeen', 0.3336341480234779), ('Fazal', 0.3257632955453822)]
# Max similarity: 0.187, Threshold: 0.5
# Similarities: [('Abdul', -0.16844729561242033), ('Adeen', 0.15269681481161046), ('Fazal', 0.18697039044256458)]
#
# 0: 480x640 3 faces, 7.9ms
# Speed: 2.0ms preprocess, 7.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Max similarity: 0.836, Threshold: 0.5
# Similarities: [('Abdul', 0.17062926292419434), ('Adeen', 0.8360199332237244), ('Fazal', 0.3303491473197937)]
# Max similarity: 0.418, Threshold: 0.5
# Similarities: [('Abdul', 0.15569879676706844), ('Adeen', 0.3969039084372582), ('Fazal', 0.41839188823748374)]
# Max similarity: 0.185, Threshold: 0.5
# Similarities: [('Abdul', -0.1991884708404541), ('Adeen', 0.15135157108306885), ('Fazal', 0.18509098887443542)]
#
# 0: 480x640 3 faces, 8.5ms
# Speed: 2.8ms preprocess, 8.5ms inference, 4.8ms postprocess per image at shape (1, 3, 480, 640)
# Max similarity: 0.839, Threshold: 0.5
# Similarities: [('Abdul', 0.1852794775200205), ('Adeen', 0.839018175660482), ('Fazal', 0.33575595404172276)]
# Max similarity: 0.459, Threshold: 0.5
# Similarities: [('Abdul', 0.15861903675681166), ('Adeen', 0.3515855162390765), ('Fazal', 0.458747240379618)]
# Max similarity: 0.195, Threshold: 0.5
# Similarities: [('Abdul', -0.20408017933368683), ('Adeen', 0.19454573094844818), ('Fazal', 0.16644984483718872)]
#
# 0: 480x640 3 faces, 11.9ms
# Speed: 2.0ms preprocess, 11.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Max similarity: 0.826, Threshold: 0.5
# Similarities: [('Abdul', 0.14547592401504517), ('Adeen', 0.8264374732971191), ('Fazal', 0.3689901828765869)]
# Max similarity: 0.405, Threshold: 0.5
# Similarities: [('Abdul', 0.11611919105052948), ('Adeen', 0.39186030626296997), ('Fazal', 0.40538305044174194)]
# Max similarity: 0.275, Threshold: 0.5
# Similarities: [('Abdul', -0.18482540547847748), ('Adeen', 0.2751366198062897), ('Fazal', 0.1854921281337738)]
#
# 0: 480x640 3 faces, 7.1ms
# Speed: 2.0ms preprocess, 7.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Max similarity: 0.829, Threshold: 0.5
# Similarities: [('Abdul', 0.15974459590050039), ('Adeen', 0.8289219242976964), ('Fazal', 0.3624899767345211)]
# Max similarity: 0.616, Threshold: 0.5
# Similarities: [('Abdul', 0.17119811944972785), ('Adeen', 0.47126892380303675), ('Fazal', 0.6157061686690957)]
# Max similarity: 0.248, Threshold: 0.5
# Similarities: [('Abdul', -0.1326303780078888), ('Adeen', 0.24792791903018951), ('Fazal', 0.15209795534610748)]
#
# 0: 480x640 3 faces, 11.2ms
# Speed: 2.0ms preprocess, 11.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Max similarity: 0.834, Threshold: 0.5
# Similarities: [('Abdul', 0.17773361934819132), ('Adeen', 0.8336213330256159), ('Fazal', 0.33053059395965434)]
# Max similarity: 0.548, Threshold: 0.5
# Similarities: [('Abdul', 0.14644071459770203), ('Adeen', 0.4407084584236145), ('Fazal', 0.5480791330337524)]
# Max similarity: 0.215, Threshold: 0.5
# Similarities: [('Abdul', -0.16715896129608154), ('Adeen', 0.2147136926651001), ('Fazal', 0.07474291324615479)]
#
# 0: 480x640 3 faces, 3.0ms
# Speed: 1.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Max similarity: 0.839, Threshold: 0.5
# Similarities: [('Abdul', 0.18309371173381805), ('Adeen', 0.839118242263794), ('Fazal', 0.3574488162994385)]
# Max similarity: 0.602, Threshold: 0.5
# Similarities: [('Abdul', 0.1840660274028778), ('Adeen', 0.45161694288253784), ('Fazal', 0.6020633578300476)]
# Max similarity: 0.233, Threshold: 0.5
# Similarities: [('Abdul', -0.13347478905470456), ('Adeen', 0.23331092397505537), ('Fazal', 0.11537308303278215)]
#
# 0: 480x640 3 faces, 11.9ms
# Speed: 2.0ms preprocess, 11.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Max similarity: 0.827, Threshold: 0.5
# Similarities: [('Abdul', 0.16208242403969653), ('Adeen', 0.8265876277334927), ('Fazal', 0.3553015079914631)]
# Max similarity: 0.589, Threshold: 0.5
# Similarities: [('Abdul', 0.17171200086402916), ('Adeen', 0.4364852645107954), ('Fazal', 0.5885521418719217)]
# Max similarity: 0.241, Threshold: 0.5
# Similarities: [('Abdul', -0.07333186268806458), ('Adeen', 0.24125578999519348), ('Fazal', 0.13411250710487366)]
#
# 0: 480x640 3 faces, 11.9ms
# Speed: 1.0ms preprocess, 11.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Max similarity: 0.809, Threshold: 0.5
# Similarities: [('Abdul', 0.13035781681537628), ('Adeen', 0.8091028332710266), ('Fazal', 0.3673473000526428)]
# Max similarity: 0.536, Threshold: 0.5
# Similarities: [('Abdul', 0.17015746711746083), ('Adeen', 0.4012862502761938), ('Fazal', 0.5355201640415104)]
# Max similarity: 0.210, Threshold: 0.5
# Similarities: [('Abdul', -0.11251725256443024), ('Adeen', 0.2099786400794983), ('Fazal', 0.12652543187141418)]
#
# 0: 480x640 3 faces, 11.9ms
# Speed: 2.0ms preprocess, 11.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Max similarity: 0.815, Threshold: 0.5
# Similarities: [('Abdul', 0.15432700514793396), ('Adeen', 0.815268874168396), ('Fazal', 0.3561410903930664)]
# Max similarity: 0.560, Threshold: 0.5
# Similarities: [('Abdul', 0.15343409776687622), ('Adeen', 0.39365002512931824), ('Fazal', 0.560434877872467)]
# Max similarity: 0.243, Threshold: 0.5
# Similarities: [('Abdul', -0.10520066320896149), ('Adeen', 0.2431507408618927), ('Fazal', 0.16481363773345947)]
#
# 0: 480x640 3 faces, 2.2ms
# Speed: 2.0ms preprocess, 2.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Max similarity: 0.822, Threshold: 0.5
# Similarities: [('Abdul', 0.1557927429676056), ('Adeen', 0.8224635124206543), ('Fazal', 0.38144758343696594)]
# Max similarity: 0.533, Threshold: 0.5
# Similarities: [('Abdul', 0.10397412753259394), ('Adeen', 0.3444965872468604), ('Fazal', 0.5333615223549899)]
# Max similarity: 0.187, Threshold: 0.5
# Similarities: [('Abdul', -0.06722638756036758), ('Adeen', 0.1873178333044052), ('Fazal', 0.030089441686868668)]
#
# 0: 480x640 3 faces, 11.9ms
# Speed: 2.0ms preprocess, 11.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Max similarity: 0.830, Threshold: 0.5
# Similarities: [('Abdul', 0.15554585125769105), ('Adeen', 0.8304782610846617), ('Fazal', 0.384469665022513)]
# Max similarity: 0.542, Threshold: 0.5
# Similarities: [('Abdul', 0.11780474334955215), ('Adeen', 0.37811219692230225), ('Fazal', 0.5423849821090698)]
# Max similarity: 0.112, Threshold: 0.5
# Similarities: [('Abdul', -0.05830493941903114), ('Adeen', 0.11200277507305145), ('Fazal', 0.041988421231508255)]
#
# 0: 480x640 3 faces, 12.9ms
# Speed: 1.0ms preprocess, 12.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Max similarity: 0.839, Threshold: 0.5
# Similarities: [('Abdul', 0.17273902893066406), ('Adeen', 0.8387525677680969), ('Fazal', 0.3754742443561554)]
# Max similarity: 0.535, Threshold: 0.5
# Similarities: [('Abdul', 0.09565553069114685), ('Adeen', 0.31529319286346436), ('Fazal', 0.535222053527832)]
# Max similarity: 0.193, Threshold: 0.5
# Similarities: [('Abdul', -0.07407497918158912), ('Adeen', 0.192839640805743), ('Fazal', 0.04522104664319482)]
#
# 0: 480x640 3 faces, 12.9ms
# Speed: 2.0ms preprocess, 12.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Max similarity: 0.832, Threshold: 0.5
# Similarities: [('Abdul', 0.15786528587341309), ('Adeen', 0.8319395780563354), ('Fazal', 0.3737742006778717)]
# Max similarity: 0.551, Threshold: 0.5
# Similarities: [('Abdul', 0.11858097502106602), ('Adeen', 0.30517927973393966), ('Fazal', 0.5508875518508234)]
# Max similarity: 0.267, Threshold: 0.5
# Similarities: [('Abdul', -0.14958418905735016), ('Adeen', 0.2674393653869629), ('Fazal', 0.17316249012947083)]
#
# 0: 480x640 3 faces, 12.9ms
# Speed: 3.0ms preprocess, 12.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Max similarity: 0.819, Threshold: 0.5
# Similarities: [('Abdul', 0.13049954175949097), ('Adeen', 0.818943977355957), ('Fazal', 0.37647610902786255)]
# Max similarity: 0.484, Threshold: 0.5
# Similarities: [('Abdul', 0.043482035398483276), ('Adeen', 0.28041934967041016), ('Fazal', 0.48424556851387024)]
# Max similarity: 0.276, Threshold: 0.5
# Similarities: [('Abdul', -0.13581358576932057), ('Adeen', 0.2756832077692032), ('Fazal', 0.18086468095393926)]
#
# 0: 480x640 3 faces, 11.9ms
# Speed: 2.0ms preprocess, 11.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Max similarity: 0.827, Threshold: 0.5
# Similarities: [('Abdul', 0.15449559688568115), ('Adeen', 0.8266568183898926), ('Fazal', 0.37720435857772827)]
# Max similarity: 0.458, Threshold: 0.5
# Similarities: [('Abdul', 0.048009876161813736), ('Adeen', 0.276519238948822), ('Fazal', 0.45839792490005493)]
# Max similarity: 0.295, Threshold: 0.5
# Similarities: [('Abdul', -0.1648801565170288), ('Adeen', 0.2951939105987549), ('Fazal', 0.15450125932693481)]
#
# 0: 480x640 3 faces, 1.4ms
# Speed: 1.0ms preprocess, 1.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Max similarity: 0.828, Threshold: 0.5
# Similarities: [('Abdul', 0.14119315147399902), ('Adeen', 0.827886700630188), ('Fazal', 0.3601400554180145)]
# Max similarity: 0.462, Threshold: 0.5
# Similarities: [('Abdul', 0.052968256175518036), ('Adeen', 0.28601548075675964), ('Fazal', 0.46213874220848083)]
# Max similarity: 0.215, Threshold: 0.5
# Similarities: [('Abdul', -0.16660961508750916), ('Adeen', 0.2148725837469101), ('Fazal', 0.16109822690486908)]
#
# 0: 480x640 3 faces, 11.9ms
# Speed: 3.0ms preprocess, 11.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Max similarity: 0.811, Threshold: 0.5
# Similarities: [('Abdul', 0.13096866011619568), ('Adeen', 0.8110272288322449), ('Fazal', 0.3451947569847107)]
# Max similarity: 0.460, Threshold: 0.5
# Similarities: [('Abdul', 0.0802374854683876), ('Adeen', 0.3832521140575409), ('Fazal', 0.4596360921859741)]
# Max similarity: 0.212, Threshold: 0.5
# Similarities: [('Abdul', -0.19006260096653715), ('Adeen', 0.21168133844844506), ('Fazal', 0.1402312433581806)]
#
# 0: 480x640 3 faces, 12.4ms
# Speed: 0.0ms preprocess, 12.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Max similarity: 0.831, Threshold: 0.5
# Similarities: [('Abdul', 0.14996556043830178), ('Adeen', 0.8314653139433092), ('Fazal', 0.35092083508248184)]
# Max similarity: 0.482, Threshold: 0.5
# Similarities: [('Abdul', 0.07634427688453949), ('Adeen', 0.40474406452512435), ('Fazal', 0.48182484615893173)]
# Max similarity: 0.220, Threshold: 0.5
# Similarities: [('Abdul', -0.19335747102752543), ('Adeen', 0.21956688347060216), ('Fazal', 0.14432967338981217)]
#
# 0: 480x640 3 faces, 11.9ms
# Speed: 2.0ms preprocess, 11.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Max similarity: 0.844, Threshold: 0.5
# Similarities: [('Abdul', 0.17416371405124664), ('Adeen', 0.8435871005058289), ('Fazal', 0.36751461029052734)]
# Max similarity: 0.454, Threshold: 0.5
# Similarities: [('Abdul', 0.06471701325672796), ('Adeen', 0.40962610187375015), ('Fazal', 0.45365605034494183)]
# Max similarity: 0.213, Threshold: 0.5
# Similarities: [('Abdul', -0.17882006294607766), ('Adeen', 0.21297538501170998), ('Fazal', 0.16353077211792666)]
#
# 0: 480x640 3 faces, 11.1ms
# Speed: 1.0ms preprocess, 11.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Max similarity: 0.846, Threshold: 0.5
# Similarities: [('Abdul', 0.1722608208656311), ('Adeen', 0.8457157611846924), ('Fazal', 0.36893129348754883)]
# Max similarity: 0.412, Threshold: 0.5
# Similarities: [('Abdul', 0.05096472054719925), ('Adeen', 0.38601234555244446), ('Fazal', 0.4120670557022095)]
# Max similarity: 0.288, Threshold: 0.5
# Similarities: [('Abdul', -0.13741227984428406), ('Adeen', 0.287886381149292), ('Fazal', 0.18961045145988464)]
#
# 0: 480x640 3 faces, 12.9ms
# Speed: 3.0ms preprocess, 12.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Max similarity: 0.845, Threshold: 0.5
# Similarities: [('Abdul', 0.163432558570352), ('Adeen', 0.8454422446821798), ('Fazal', 0.35940567496981246)]
# Max similarity: 0.402, Threshold: 0.5
# Similarities: [('Abdul', 0.016093491548687777), ('Adeen', 0.38780299497825), ('Fazal', 0.4016886412090881)]
# Max similarity: 0.264, Threshold: 0.5
# Similarities: [('Abdul', -0.15285985627352772), ('Adeen', 0.26376170706038804), ('Fazal', 0.2297574052142325)]
#
# 0: 480x640 3 faces, 12.6ms
# Speed: 1.0ms preprocess, 12.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Max similarity: 0.847, Threshold: 0.5
# Similarities: [('Abdul', 0.15309710800647736), ('Adeen', 0.8472871780395508), ('Fazal', 0.3528195321559906)]
# Max similarity: 0.361, Threshold: 0.5
# Similarities: [('Abdul', -0.05953683331608772), ('Adeen', 0.3540910482406616), ('Fazal', 0.36057084798812866)]
# Max similarity: 0.256, Threshold: 0.5
# Similarities: [('Abdul', -0.18265914916992188), ('Adeen', 0.25551876425743103), ('Fazal', 0.1825275719165802)]
#
# 0: 480x640 2 faces, 11.9ms
# Speed: 2.0ms preprocess, 11.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Max similarity: 0.838, Threshold: 0.5
# Similarities: [('Abdul', 0.1370984532178372), ('Adeen', 0.8384053207394304), ('Fazal', 0.36105344527641337)]
# Max similarity: 0.361, Threshold: 0.5
# Similarities: [('Abdul', -0.11112283501395104), ('Adeen', 0.3302096226873883), ('Fazal', 0.3608927238253572)]
#
# 0: 480x640 2 faces, 11.0ms
# Speed: 2.0ms preprocess, 11.0ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
# Max similarity: 0.849, Threshold: 0.5
# Similarities: [('Abdul', 0.14870228477106806), ('Adeen', 0.8490538091031442), ('Fazal', 0.343820074568983)]
# Max similarity: 0.362, Threshold: 0.5
# Similarities: [('Abdul', -0.11657758057117462), ('Adeen', 0.3526979088783264), ('Fazal', 0.3618289828300476)]
#
# 0: 480x640 2 faces, 11.9ms
# Speed: 2.0ms preprocess, 11.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Max similarity: 0.836, Threshold: 0.5
# Similarities: [('Abdul', 0.13015421449218922), ('Adeen', 0.8362110354774588), ('Fazal', 0.327505926638489)]
# Max similarity: 0.375, Threshold: 0.5
# Similarities: [('Abdul', -0.13662920892238617), ('Adeen', 0.35758176445961), ('Fazal', 0.3745158314704895)]
#
# 0: 480x640 2 faces, 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Max similarity: 0.841, Threshold: 0.5
# Similarities: [('Abdul', 0.13359174132347107), ('Adeen', 0.840621292591095), ('Fazal', 0.3248651623725891)]
# Max similarity: 0.379, Threshold: 0.5
# Similarities: [('Abdul', -0.10364906617110581), ('Adeen', 0.3788008762120685), ('Fazal', 0.3213534163622018)]
#
# 0: 480x640 2 faces, 2.0ms
# Speed: 1.0ms preprocess, 2.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Max similarity: 0.838, Threshold: 0.5
# Similarities: [('Abdul', 0.14156478643417358), ('Adeen', 0.8382214903831482), ('Fazal', 0.34140634536743164)]
# Max similarity: 0.307, Threshold: 0.5
# Similarities: [('Abdul', -0.1310354691126665), ('Adeen', 0.2825050185617799), ('Fazal', 0.3073478157909032)]
#
# 0: 480x640 2 faces, 11.9ms
# Speed: 2.0ms preprocess, 11.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Max similarity: 0.839, Threshold: 0.5
# Similarities: [('Abdul', 0.13453974517943013), ('Adeen', 0.8393054104265341), ('Fazal', 0.33607081555898155)]
# Max similarity: 0.329, Threshold: 0.5
# Similarities: [('Abdul', -0.08348290622234344), ('Adeen', 0.3294963240623474), ('Fazal', 0.3232356309890747)]
#
# 0: 480x640 2 faces, 11.9ms
# Speed: 2.0ms preprocess, 11.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Max similarity: 0.832, Threshold: 0.5
# Similarities: [('Abdul', 0.1479131579399109), ('Adeen', 0.8316699266433716), ('Fazal', 0.3393644094467163)]
# Max similarity: 0.428, Threshold: 0.5
# Similarities: [('Abdul', 0.08003673702478409), ('Adeen', 0.3578093945980072), ('Fazal', 0.42773181200027466)]
#
# 0: 480x640 2 faces, 3.9ms
# Speed: 1.0ms preprocess, 3.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Max similarity: 0.836, Threshold: 0.5
# Similarities: [('Abdul', 0.152237668633461), ('Adeen', 0.8359125256538391), ('Fazal', 0.347950279712677)]
# Max similarity: 0.343, Threshold: 0.5
# Similarities: [('Abdul', 0.07285600466394415), ('Adeen', 0.31986347914555857), ('Fazal', 0.34308002334356225)]
#
# 0: 480x640 2 faces, 11.3ms
# Speed: 2.0ms preprocess, 11.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Max similarity: 0.835, Threshold: 0.5
# Similarities: [('Abdul', 0.1387156529765553), ('Adeen', 0.8350890475405457), ('Fazal', 0.3574752083450332)]
# Max similarity: 0.358, Threshold: 0.5
# Similarities: [('Abdul', 0.050834380090236664), ('Adeen', 0.3114217519760132), ('Fazal', 0.3577136695384979)]
#
# 0: 480x640 2 faces, 11.0ms
# Speed: 1.4ms preprocess, 11.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Max similarity: 0.829, Threshold: 0.5
# Similarities: [('Abdul', 0.14073624368093973), ('Adeen', 0.8290818435500968), ('Fazal', 0.35142973950924106)]
# Max similarity: 0.460, Threshold: 0.5
# Similarities: [('Abdul', 0.22130055725574493), ('Adeen', 0.4604357182979584), ('Fazal', 0.4523044228553772)]
#
# 0: 480x640 2 faces, 11.3ms
# Speed: 1.0ms preprocess, 11.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Max similarity: 0.835, Threshold: 0.5
# Similarities: [('Abdul', 0.12970577897395041), ('Adeen', 0.8352556922879417), ('Fazal', 0.37273333235184425)]
# Max similarity: 0.363, Threshold: 0.5
# Similarities: [('Abdul', 0.026509629845045235), ('Adeen', 0.3632082722658956), ('Fazal', 0.3358556130018471)]
#
# 0: 480x640 2 faces, 11.5ms
# Speed: 2.0ms preprocess, 11.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Max similarity: 0.830, Threshold: 0.5
# Similarities: [('Abdul', 0.1499004364013672), ('Adeen', 0.8296149969100952), ('Fazal', 0.3940272927284241)]
# Max similarity: 0.329, Threshold: 0.5
# Similarities: [('Abdul', -0.05060860142111778), ('Adeen', 0.298974871635437), ('Fazal', 0.32925012707710266)]
#
# 0: 480x640 2 faces, 12.4ms
# Speed: 1.0ms preprocess, 12.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Max similarity: 0.825, Threshold: 0.5
# Similarities: [('Abdul', 0.1409223973751068), ('Adeen', 0.8250547647476196), ('Fazal', 0.37966006994247437)]
# Max similarity: 0.328, Threshold: 0.5
# Similarities: [('Abdul', -0.05471411393796721), ('Adeen', 0.2940818790148574), ('Fazal', 0.327797154915503)]
#
# 0: 480x640 2 faces, 12.4ms
# Speed: 1.4ms preprocess, 12.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Max similarity: 0.833, Threshold: 0.5
# Similarities: [('Abdul', 0.17523039278621888), ('Adeen', 0.832876463785599), ('Fazal', 0.38612709806834755)]
# Max similarity: 0.367, Threshold: 0.5
# Similarities: [('Abdul', -0.028229055926203728), ('Adeen', 0.2616702914237976), ('Fazal', 0.3667486310005188)]
#
# 0: 480x640 2 faces, 12.2ms
# Speed: 2.0ms preprocess, 12.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Max similarity: 0.826, Threshold: 0.5
# Similarities: [('Abdul', 0.18833494186401367), ('Adeen', 0.8261039853096008), ('Fazal', 0.40141046047210693)]
# Max similarity: 0.401, Threshold: 0.5
# Similarities: [('Abdul', -0.008165880550987659), ('Adeen', 0.26612006031751323), ('Fazal', 0.40109688633102936)]
#
# 0: 480x640 2 faces, 12.9ms
# Speed: 1.0ms preprocess, 12.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Max similarity: 0.810, Threshold: 0.5
# Similarities: [('Abdul', 0.21074344451764593), ('Adeen', 0.8101778739584774), ('Fazal', 0.411963378670015)]
# Max similarity: 0.385, Threshold: 0.5
# Similarities: [('Abdul', -0.028376761823892593), ('Adeen', 0.2394857406616211), ('Fazal', 0.385398805141449)]
#
# 0: 480x640 2 faces, 3.4ms
# Speed: 1.0ms preprocess, 3.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Max similarity: 0.785, Threshold: 0.5
# Similarities: [('Abdul', 0.15772277116775513), ('Adeen', 0.785437822341919), ('Fazal', 0.3847235441207886)]
# Max similarity: 0.376, Threshold: 0.5
# Similarities: [('Abdul', -0.021771185665059978), ('Adeen', 0.28307871323354816), ('Fazal', 0.3763497247487477)]
#
# 0: 480x640 2 faces, 11.5ms
# Speed: 2.0ms preprocess, 11.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Max similarity: 0.794, Threshold: 0.5
# Similarities: [('Abdul', 0.22317330539226532), ('Adeen', 0.79377681016922), ('Fazal', 0.38471055030822754)]
# Max similarity: 0.350, Threshold: 0.5
# Similarities: [('Abdul', -0.02164304256439209), ('Adeen', 0.2673072814941406), ('Fazal', 0.3502418100833893)]
#
# 0: 480x640 2 faces, 11.9ms
# Speed: 2.0ms preprocess, 11.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Max similarity: 0.815, Threshold: 0.5
# Similarities: [('Abdul', 0.18610993027687073), ('Adeen', 0.8153424263000488), ('Fazal', 0.3757355213165283)]
# Max similarity: 0.351, Threshold: 0.5
# Similarities: [('Abdul', -0.002437654882669449), ('Adeen', 0.2682701349258423), ('Fazal', 0.35053086280822754)]
#
# 0: 480x640 2 faces, 11.0ms
# Speed: 2.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Max similarity: 0.807, Threshold: 0.5
# Similarities: [('Abdul', 0.1830860674381256), ('Adeen', 0.8074297308921814), ('Fazal', 0.40620744228363037)]
# Max similarity: 0.421, Threshold: 0.5
# Similarities: [('Abdul', -0.006171582266688347), ('Adeen', 0.28820332884788513), ('Fazal', 0.42148756980895996)]
#
# 0: 480x640 2 faces, 13.7ms
# Speed: 0.0ms preprocess, 13.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Max similarity: 0.831, Threshold: 0.5
# Similarities: [('Abdul', 0.15521621704101562), ('Adeen', 0.8313567638397217), ('Fazal', 0.3543058931827545)]
# Max similarity: 0.408, Threshold: 0.5
# Similarities: [('Abdul', -0.01698094792664051), ('Adeen', 0.29706433415412903), ('Fazal', 0.4079575538635254)]
#
# 0: 480x640 2 faces, 11.9ms
# Speed: 1.0ms preprocess, 11.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Max similarity: 0.823, Threshold: 0.5
# Similarities: [('Abdul', 0.16131891310214996), ('Adeen', 0.8233380317687988), ('Fazal', 0.36779600381851196)]
# Max similarity: 0.406, Threshold: 0.5
# Similarities: [('Abdul', -0.008531633764505386), ('Adeen', 0.2854778468608856), ('Fazal', 0.40595418214797974)]
#
# 0: 480x640 2 faces, 11.0ms
# Speed: 2.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Max similarity: 0.840, Threshold: 0.5
# Similarities: [('Abdul', 0.19576460446330324), ('Adeen', 0.8399251794859675), ('Fazal', 0.37934619907461475)]
# Max similarity: 0.402, Threshold: 0.5
# Similarities: [('Abdul', -0.011513032019138336), ('Adeen', 0.28027862310409546), ('Fazal', 0.40225374698638916)]
#
# 0: 480x640 2 faces, 11.9ms
# Speed: 2.0ms preprocess, 11.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Max similarity: 0.847, Threshold: 0.5
# Similarities: [('Abdul', 0.17470219731330872), ('Adeen', 0.8472669124603271), ('Fazal', 0.34739792346954346)]
# Max similarity: 0.408, Threshold: 0.5
# Similarities: [('Abdul', -0.0008401199674534787), ('Adeen', 0.28483651370784613), ('Fazal', 0.40835473487647045)]
#
# 0: 480x640 2 faces, 0.0ms
# Speed: 1.5ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Max similarity: 0.865, Threshold: 0.5
# Similarities: [('Abdul', 0.2166197617876675), ('Adeen', 0.8654304226976397), ('Fazal', 0.35402716076212226)]
# Max similarity: 0.367, Threshold: 0.5
# Similarities: [('Abdul', -0.0597301684319973), ('Adeen', 0.29063189029693604), ('Fazal', 0.36679506301879883)]
#
# 0: 480x640 2 faces, 11.6ms
# Speed: 2.0ms preprocess, 11.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Max similarity: 0.870, Threshold: 0.5
# Similarities: [('Abdul', 0.23072129602901403), ('Adeen', 0.8704385238624515), ('Fazal', 0.3515644459984043)]
# Max similarity: 0.361, Threshold: 0.5
# Similarities: [('Abdul', -0.04492754489183426), ('Adeen', 0.28305870294570923), ('Fazal', 0.36112648248672485)]
#
# 0: 480x640 2 faces, 13.9ms
# Speed: 1.0ms preprocess, 13.9ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
# Max similarity: 0.872, Threshold: 0.5
# Similarities: [('Abdul', 0.23750928044319153), ('Adeen', 0.8715066313743591), ('Fazal', 0.3523944318294525)]
# Max similarity: 0.443, Threshold: 0.5
# Similarities: [('Abdul', -0.03129616938256219), ('Adeen', 0.28441361877837124), ('Fazal', 0.44257650121590564)]
#
# 0: 480x640 2 faces, 10.1ms
# Speed: 2.0ms preprocess, 10.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Max similarity: 0.835, Threshold: 0.5
# Similarities: [('Abdul', 0.21691817045211792), ('Adeen', 0.8348076939582825), ('Fazal', 0.3773759603500366)]
# Max similarity: 0.341, Threshold: 0.5
# Similarities: [('Abdul', -0.06390231847763062), ('Adeen', 0.2726380228996277), ('Fazal', 0.3409034013748169)]
#
# 0: 480x640 2 faces, 12.8ms
# Speed: 1.6ms preprocess, 12.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Max similarity: 0.837, Threshold: 0.5
# Similarities: [('Abdul', 0.2517384886741638), ('Adeen', 0.8366441130638123), ('Fazal', 0.40161198377609253)]
# Max similarity: 0.441, Threshold: 0.5
# Similarities: [('Abdul', 0.05906239151954651), ('Adeen', 0.3583635985851288), ('Fazal', 0.44058650732040405)]
#
# 0: 480x640 2 faces, 12.8ms
# Speed: 0.0ms preprocess, 12.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Max similarity: 0.839, Threshold: 0.5
# Similarities: [('Abdul', 0.29577187920976455), ('Adeen', 0.8387119270138799), ('Fazal', 0.40163443078789607)]
# Max similarity: 0.430, Threshold: 0.5
# Similarities: [('Abdul', 0.10442799452376417), ('Adeen', 0.3069887872344983), ('Fazal', 0.4299928885702564)]
#
# 0: 480x640 2 faces, 20.9ms
# Speed: 2.9ms preprocess, 20.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Max similarity: 0.824, Threshold: 0.5
# Similarities: [('Abdul', 0.24350960591378223), ('Adeen', 0.8236181245077789), ('Fazal', 0.37296799582433793)]
# Max similarity: 0.429, Threshold: 0.5
# Similarities: [('Abdul', 0.10773740708827972), ('Adeen', 0.317211389541626), ('Fazal', 0.4291836619377136)]
#
# 0: 480x640 2 faces, 11.9ms
# Speed: 2.0ms preprocess, 11.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Max similarity: 0.810, Threshold: 0.5
# Similarities: [('Abdul', 0.1884398944115705), ('Adeen', 0.809867810614837), ('Fazal', 0.3646331212143237)]
# Max similarity: 0.432, Threshold: 0.5
# Similarities: [('Abdul', 0.11312045156955719), ('Adeen', 0.3195478320121765), ('Fazal', 0.4315218925476074)]
#
# 0: 480x640 2 faces, 12.9ms
# Speed: 1.0ms preprocess, 12.9ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
# Max similarity: 0.808, Threshold: 0.5
# Similarities: [('Abdul', 0.1662113070487976), ('Adeen', 0.8076331615447998), ('Fazal', 0.3456335961818695)]
# Max similarity: 0.366, Threshold: 0.5
# Similarities: [('Abdul', 0.07490942627191544), ('Adeen', 0.2707020044326782), ('Fazal', 0.3663559556007385)]
#
# 0: 480x640 2 faces, 11.9ms
# Speed: 2.0ms preprocess, 11.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Max similarity: 0.823, Threshold: 0.5
# Similarities: [('Abdul', 0.1764937683049581), ('Adeen', 0.8232061372276478), ('Fazal', 0.3627616844915347)]
# Max similarity: 0.360, Threshold: 0.5
# Similarities: [('Abdul', 0.05543112754821777), ('Adeen', 0.276588499546051), ('Fazal', 0.3600652515888214)]
#
# 0: 480x640 2 faces, 11.9ms
# Speed: 2.0ms preprocess, 11.9ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
# Max similarity: 0.828, Threshold: 0.5
# Similarities: [('Abdul', 0.1819433569908142), ('Adeen', 0.8284460306167603), ('Fazal', 0.34229063987731934)]
# Max similarity: 0.412, Threshold: 0.5
# Similarities: [('Abdul', 0.003817562013864517), ('Adeen', 0.292151540517807), ('Fazal', 0.4124918580055237)]
#
# 0: 480x640 2 faces, 9.4ms
# Speed: 2.0ms preprocess, 9.4ms inference, 4.3ms postprocess per image at shape (1, 3, 480, 640)
# Max similarity: 0.835, Threshold: 0.5
# Similarities: [('Abdul', 0.18108831756780674), ('Adeen', 0.8348313072424363), ('Fazal', 0.3730867878742947)]
# Max similarity: 0.424, Threshold: 0.5
# Similarities: [('Abdul', 0.10051699873703746), ('Adeen', 0.34147013178645835), ('Fazal', 0.42359015801011646)]
#
# 0: 480x640 2 faces, 11.4ms
# Speed: 2.0ms preprocess, 11.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Max similarity: 0.832, Threshold: 0.5
# Similarities: [('Abdul', 0.17733291848498123), ('Adeen', 0.8318240542306947), ('Fazal', 0.36891444736209267)]
# Max similarity: 0.330, Threshold: 0.5
# Similarities: [('Abdul', 0.046704839915037155), ('Adeen', 0.330379843711853), ('Fazal', 0.3264255225658417)]
#
# 0: 480x640 2 faces, 11.9ms
# Speed: 2.0ms preprocess, 11.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Max similarity: 0.813, Threshold: 0.5
# Similarities: [('Abdul', 0.12906044721603394), ('Adeen', 0.8130998611450195), ('Fazal', 0.3651409149169922)]
# Max similarity: 0.321, Threshold: 0.5
# Similarities: [('Abdul', 0.014071491639525258), ('Adeen', 0.27624244831547506), ('Fazal', 0.3214466976257153)]
#
# 0: 480x640 2 faces, 2.9ms
# Speed: 1.0ms preprocess, 2.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Max similarity: 0.801, Threshold: 0.5
# Similarities: [('Abdul', 0.09004959672393831), ('Adeen', 0.8006102561586956), ('Fazal', 0.33592758560612346)]
# Max similarity: 0.354, Threshold: 0.5
# Similarities: [('Abdul', 0.03554346784949303), ('Adeen', 0.31036242842674255), ('Fazal', 0.3543929159641266)]
#
# 0: 480x640 2 faces, 11.9ms
# Speed: 2.0ms preprocess, 11.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Max similarity: 0.801, Threshold: 0.5
# Similarities: [('Abdul', 0.14788652956485748), ('Adeen', 0.8013135194778442), ('Fazal', 0.3639519512653351)]
# Max similarity: 0.401, Threshold: 0.5
# Similarities: [('Abdul', 0.008756890892982483), ('Adeen', 0.31070178747177124), ('Fazal', 0.4008498787879944)]
#
# 0: 480x640 2 faces, 11.7ms
# Speed: 2.0ms preprocess, 11.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Max similarity: 0.828, Threshold: 0.5
# Similarities: [('Abdul', 0.20312945824089934), ('Adeen', 0.8284348947742659), ('Fazal', 0.3957997026562875)]
# Max similarity: 0.391, Threshold: 0.5
# Similarities: [('Abdul', 0.07370305061340332), ('Adeen', 0.3663816452026367), ('Fazal', 0.39106109738349915)]
#
# 0: 480x640 2 faces, 15.0ms
# Speed: 0.0ms preprocess, 15.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Max similarity: 0.823, Threshold: 0.5
# Similarities: [('Abdul', 0.19886362552642822), ('Adeen', 0.8229129910469055), ('Fazal', 0.3848644495010376)]
# Max similarity: 0.390, Threshold: 0.5
# Similarities: [('Abdul', 0.04489512101440907), ('Adeen', 0.3896594113314509), ('Fazal', 0.37997124314479636)]
#
# 0: 480x640 2 faces, 12.0ms
# Speed: 2.8ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Max similarity: 0.820, Threshold: 0.5
# Similarities: [('Abdul', 0.19989466667175293), ('Adeen', 0.8200376629829407), ('Fazal', 0.3724558651447296)]
# Max similarity: 0.373, Threshold: 0.5
# Similarities: [('Abdul', -0.04928464148732181), ('Adeen', 0.37230757639959067), ('Fazal', 0.3726738171175834)]
#
# 0: 480x640 2 faces, 11.9ms
# Speed: 1.0ms preprocess, 11.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Max similarity: 0.825, Threshold: 0.5
# Similarities: [('Abdul', 0.2157415747642517), ('Adeen', 0.8247822523117065), ('Fazal', 0.37620702385902405)]
# Max similarity: 0.377, Threshold: 0.5
# Similarities: [('Abdul', -0.053226884454488754), ('Adeen', 0.37038981914520264), ('Fazal', 0.3770655393600464)]
#
# 0: 480x640 2 faces, 11.9ms
# Speed: 2.0ms preprocess, 11.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Max similarity: 0.852, Threshold: 0.5
# Similarities: [('Abdul', 0.24292367696762085), ('Adeen', 0.8516806364059448), ('Fazal', 0.38780683279037476)]
# Max similarity: 0.402, Threshold: 0.5
# Similarities: [('Abdul', -0.05445219576358795), ('Adeen', 0.40179648995399475), ('Fazal', 0.3726987838745117)]
#
# 0: 480x640 2 faces, 11.9ms
# Speed: 2.0ms preprocess, 11.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Max similarity: 0.850, Threshold: 0.5
# Similarities: [('Abdul', 0.22132962942123413), ('Adeen', 0.850099503993988), ('Fazal', 0.37513911724090576)]
# Max similarity: 0.403, Threshold: 0.5
# Similarities: [('Abdul', 0.007370419800281525), ('Adeen', 0.4027784466743469), ('Fazal', 0.38565129041671753)]
#
# 0: 480x640 2 faces, 7.7ms
# Speed: 2.0ms preprocess, 7.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Max similarity: 0.853, Threshold: 0.5
# ...
# Max similarity: 0.801, Threshold: 0.5
# Similarities: [('Abdul', 0.15176576375961304), ('Adeen', 0.8006844520568848), ('Fazal', 0.4484792947769165)]
#
# 0: 480x640 1 face, 11.9ms
# Speed: 2.0ms preprocess, 11.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Max similarity: 0.796, Threshold: 0.5
# Similarities: [('Abdul', 0.13602693378925323), ('Adeen', 0.7961793541908264), ('Fazal', 0.4352664351463318)]
#
# 0: 480x640 1 face, 11.9ms
# Speed: 1.0ms preprocess, 11.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Max similarity: 0.789, Threshold: 0.5
# Similarities: [('Abdul', 0.15230919095168327), ('Adeen', 0.7894829166551984), ('Fazal', 0.43995142698867307)]
#
# 0: 480x640 1 face, 12.9ms
# Speed: 1.0ms preprocess, 12.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Max similarity: 0.821, Threshold: 0.5
# Similarities: [('Abdul', 0.17782544029799485), ('Adeen', 0.8207855927475948), ('Fazal', 0.43391487396270867)]
#
# 0: 480x640 1 face, 11.9ms
# Speed: 1.0ms preprocess, 11.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Max similarity: 0.820, Threshold: 0.5
# Similarities: [('Abdul', 0.15596746468737965), ('Adeen', 0.8202831256220876), ('Fazal', 0.4112906210845346)]
#
# 0: 480x640 1 face, 7.0ms
# Speed: 1.6ms preprocess, 7.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Max similarity: 0.826, Threshold: 0.5
# Similarities: [('Abdul', 0.19900740683078766), ('Adeen', 0.8261206150054932), ('Fazal', 0.40856945514678955)]
#
# 0: 480x640 1 face, 11.9ms
# Speed: 2.0ms preprocess, 11.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Max similarity: 0.824, Threshold: 0.5
# Similarities: [('Abdul', 0.20629513263702393), ('Adeen', 0.8235219717025757), ('Fazal', 0.3747272491455078)]
#
# 0: 480x640 1 face, 11.9ms
# Speed: 1.0ms preprocess, 11.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Max similarity: 0.802, Threshold: 0.5
# Similarities: [('Abdul', 0.16758288443088531), ('Adeen', 0.802053689956665), ('Fazal', 0.3479796051979065)]
#
# 0: 480x640 1 face, 12.2ms
# Speed: 2.0ms preprocess, 12.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Max similarity: 0.800, Threshold: 0.5
# Similarities: [('Abdul', 0.18546997395336817), ('Adeen', 0.7996490717143387), ('Fazal', 0.3762379660464552)]
#
# 0: 480x640 1 face, 11.0ms
# Speed: 2.3ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Max similarity: 0.764, Threshold: 0.5
# Similarities: [('Abdul', 0.18388068675994873), ('Adeen', 0.7643499374389648), ('Fazal', 0.42309534549713135)]
#
# 0: 480x640 1 face, 12.9ms
# Speed: 1.0ms preprocess, 12.9ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
# Max similarity: 0.774, Threshold: 0.5
# Similarities: [('Abdul', 0.16071823239326477), ('Adeen', 0.773625910282135), ('Fazal', 0.4111506938934326)]
#
# 0: 480x640 1 face, 11.9ms
# Speed: 1.6ms preprocess, 11.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Max similarity: 0.759, Threshold: 0.5
# Similarities: [('Abdul', 0.19464293122291565), ('Adeen', 0.7585973739624023), ('Fazal', 0.43535709381103516)]
#
# 0: 480x640 1 face, 12.4ms
# Speed: 2.0ms preprocess, 12.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Max similarity: 0.780, Threshold: 0.5
# Similarities: [('Abdul', 0.15312087535858154), ('Adeen', 0.7803502082824707), ('Fazal', 0.42748183012008667)]
#
# 0: 480x640 1 face, 11.9ms
# Speed: 2.0ms preprocess, 11.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Max similarity: 0.790, Threshold: 0.5
# Similarities: [('Abdul', 0.14880821108818054), ('Adeen', 0.7896391153335571), ('Fazal', 0.4054376184940338)]
#
# 0: 480x640 1 face, 11.0ms
# Speed: 2.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Max similarity: 0.781, Threshold: 0.5
# Similarities: [('Abdul', 0.1519865095615387), ('Adeen', 0.781429648399353), ('Fazal', 0.39516741037368774)]
#
# 0: 480x640 1 face, 13.0ms
# Speed: 1.4ms preprocess, 13.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Max similarity: 0.836, Threshold: 0.5
# Similarities: [('Abdul', 0.2029079794883728), ('Adeen', 0.8363966345787048), ('Fazal', 0.39489659667015076)]
#
# 0: 480x640 1 face, 8.2ms
# Speed: 2.0ms preprocess, 8.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Max similarity: 0.821, Threshold: 0.5
# Similarities: [('Abdul', 0.22449326515197754), ('Adeen', 0.8214468955993652), ('Fazal', 0.3596012592315674)]
#
# 0: 480x640 1 face, 11.9ms
# Speed: 1.0ms preprocess, 11.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Max similarity: 0.826, Threshold: 0.5
# Similarities: [('Abdul', 0.2678380012512207), ('Adeen', 0.826041579246521), ('Fazal', 0.3635326623916626)]
#
# 0: 480x640 1 face, 11.9ms
# Speed: 1.0ms preprocess, 11.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Max similarity: 0.807, Threshold: 0.5
# Similarities: [('Abdul', 0.1968872845172882), ('Adeen', 0.8068689107894897), ('Fazal', 0.3648681044578552)]
#
# 0: 480x640 2 faces, 11.6ms
# Speed: 2.0ms preprocess, 11.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Max similarity: 0.787, Threshold: 0.5
# Similarities: [('Abdul', 0.1642257571220398), ('Adeen', 0.7874017953872681), ('Fazal', 0.3131437301635742)]
# Max similarity: 0.250, Threshold: 0.5
# Similarities: [('Abdul', -0.01237549279627248), ('Adeen', 0.14231284604592076), ('Fazal', 0.2500482052535893)]
#
# 0: 480x640 2 faces, 0.0ms
# Speed: 1.0ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Max similarity: 0.780, Threshold: 0.5
# Similarities: [('Abdul', 0.1785285770893097), ('Adeen', 0.7799026370048523), ('Fazal', 0.3066711127758026)]
# Max similarity: 0.388, Threshold: 0.5
# Similarities: [('Abdul', 0.1789744347333908), ('Adeen', 0.029567668214440346), ('Fazal', 0.3876035809516907)]
#
# 0: 480x640 2 faces, 12.9ms
# Speed: 1.0ms preprocess, 12.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Max similarity: 0.709, Threshold: 0.5
# Similarities: [('Abdul', 0.07182823121547699), ('Adeen', 0.7089788913726807), ('Fazal', 0.1773008108139038)]
# Max similarity: 0.340, Threshold: 0.5
# Similarities: [('Abdul', 0.12253458067568679), ('Adeen', 0.18619111560636104), ('Fazal', 0.3397344744363746)]
#
# 0: 480x640 2 faces, 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
# Max similarity: 0.763, Threshold: 0.5
# Similarities: [('Abdul', 0.1298455816599382), ('Adeen', 0.7631747267738161), ('Fazal', 0.1988360465266681)]
# Max similarity: 0.216, Threshold: 0.5
# Similarities: [('Abdul', 0.06800800156545639), ('Adeen', 0.15193231988356615), ('Fazal', 0.2157949229601075)]
#
# 0: 480x640 2 faces, 0.0ms
# Speed: 1.4ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Max similarity: 0.748, Threshold: 0.5
# Similarities: [('Abdul', 0.1348676085472107), ('Adeen', 0.747947096824646), ('Fazal', 0.2083943635225296)]
# Max similarity: 0.204, Threshold: 0.5
# Similarities: [('Abdul', 0.034570321440696716), ('Adeen', 0.13547053933143616), ('Fazal', 0.20380805432796478)]
#
# 0: 480x640 2 faces, 11.9ms
# Speed: 2.0ms preprocess, 11.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Max similarity: 0.721, Threshold: 0.5
# Similarities: [('Abdul', 0.1996273249387741), ('Adeen', 0.720639705657959), ('Fazal', 0.22398945689201355)]
# Max similarity: 0.285, Threshold: 0.5
# Similarities: [('Abdul', 0.08500447869300842), ('Adeen', 0.17393746972084045), ('Fazal', 0.28473711013793945)]
#
# 0: 480x640 2 faces, 11.9ms
# Speed: 1.0ms preprocess, 11.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Max similarity: 0.667, Threshold: 0.5
# Similarities: [('Abdul', 0.17685052752494812), ('Adeen', 0.6665117144584656), ('Fazal', 0.16777324676513672)]
# Max similarity: 0.350, Threshold: 0.5
# Similarities: [('Abdul', 0.1676468551158905), ('Adeen', 0.20291243493556976), ('Fazal', 0.35023853182792664)]
#
# 0: 480x640 2 faces, 19.8ms
# Speed: 2.0ms preprocess, 19.8ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Max similarity: 0.691, Threshold: 0.5
# Similarities: [('Abdul', 0.23725789861334023), ('Adeen', 0.6914736216382026), ('Fazal', 0.19368656315287602)]
# Max similarity: 0.348, Threshold: 0.5
# Similarities: [('Abdul', 0.18370344139913108), ('Adeen', 0.1501403957521682), ('Fazal', 0.34839526722459446)]
#
# 0: 480x640 2 faces, 12.9ms
# Speed: 1.0ms preprocess, 12.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Max similarity: 0.681, Threshold: 0.5
# Similarities: [('Abdul', 0.2561910152435303), ('Adeen', 0.6810218691825867), ('Fazal', 0.1660575121641159)]
# Max similarity: 0.459, Threshold: 0.5
# Similarities: [('Abdul', 0.24529606103897095), ('Adeen', 0.2628574073314667), ('Fazal', 0.45934516191482544)]
#
# 0: 480x640 2 faces, 11.9ms
# Speed: 2.0ms preprocess, 11.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Max similarity: 0.657, Threshold: 0.5
# Similarities: [('Abdul', 0.18233972787857056), ('Adeen', 0.6565373539924622), ('Fazal', 0.18359677493572235)]
# Max similarity: 0.460, Threshold: 0.5
# Similarities: [('Abdul', 0.2449229508638382), ('Adeen', 0.26869329810142517), ('Fazal', 0.4596754014492035)]
#
# 0: 480x640 2 faces, 11.9ms
# Speed: 2.0ms preprocess, 11.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Max similarity: 0.702, Threshold: 0.5
# Similarities: [('Abdul', 0.2028411328792572), ('Adeen', 0.7022541165351868), ('Fazal', 0.20296740531921387)]
# Max similarity: 0.449, Threshold: 0.5
# Similarities: [('Abdul', 0.22829903791552597), ('Adeen', 0.2740422919963429), ('Fazal', 0.44873074002678837)]
#
# 0: 480x640 2 faces, 0.0ms
# Speed: 0.2ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Max similarity: 0.717, Threshold: 0.5
# Similarities: [('Abdul', 0.16521820425987244), ('Adeen', 0.717383623123169), ('Fazal', 0.22842559218406677)]
# Max similarity: 0.433, Threshold: 0.5
# Similarities: [('Abdul', 0.2808811497163093), ('Adeen', 0.3112804406118136), ('Fazal', 0.4332592229092592)]
#
# 0: 480x640 2 faces, 12.9ms
# Speed: 1.0ms preprocess, 12.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Max similarity: 0.719, Threshold: 0.5
# Similarities: [('Abdul', 0.175532728433609), ('Adeen', 0.7194883823394775), ('Fazal', 0.281210333108902)]
# Max similarity: 0.477, Threshold: 0.5
# Similarities: [('Abdul', 0.20244400486683856), ('Adeen', 0.27416176949967375), ('Fazal', 0.47681638736627263)]
#
# 0: 480x640 2 faces, 11.9ms
# Speed: 2.0ms preprocess, 11.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Max similarity: 0.715, Threshold: 0.5
# Similarities: [('Abdul', 0.13417660390278097), ('Adeen', 0.7149620822094642), ('Fazal', 0.20703928428654206)]
# Max similarity: 0.487, Threshold: 0.5
# Similarities: [('Abdul', 0.2198459953069687), ('Adeen', 0.2890423536300659), ('Fazal', 0.48691344261169434)]
#
# 0: 480x640 2 faces, 2.0ms
# Speed: 1.0ms preprocess, 2.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Max similarity: 0.732, Threshold: 0.5
# Similarities: [('Abdul', 0.14342537302668523), ('Adeen', 0.7323767265824458), ('Fazal', 0.18915847669142893)]
# Max similarity: 0.480, Threshold: 0.5
# Similarities: [('Abdul', 0.10086806863546371), ('Adeen', 0.10900867730379105), ('Fazal', 0.48037803173065186)]
#
# 0: 480x640 2 faces, 11.9ms
# Speed: 1.0ms preprocess, 11.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Max similarity: 0.712, Threshold: 0.5
# Similarities: [('Abdul', 0.10619623326085625), ('Adeen', 0.7124248318418973), ('Fazal', 0.18307255607410966)]
# Max similarity: 0.477, Threshold: 0.5
# Similarities: [('Abdul', 0.09815555065870285), ('Adeen', 0.08607681095600128), ('Fazal', 0.4770583212375641)]
#
# 0: 480x640 2 faces, 11.9ms
# Speed: 1.7ms preprocess, 11.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Max similarity: 0.723, Threshold: 0.5
# Similarities: [('Abdul', 0.09335997332811741), ('Adeen', 0.7230397793007212), ('Fazal', 0.17567224196526632)]
# Max similarity: 0.234, Threshold: 0.5
# Similarities: [('Abdul', 0.03438728097753052), ('Adeen', 0.1897118127517815), ('Fazal', 0.23421640788218967)]
#
# 0: 480x640 2 faces, 11.9ms
# Speed: 2.0ms preprocess, 11.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Max similarity: 0.766, Threshold: 0.5
# Similarities: [('Abdul', 0.1741417646408081), ('Adeen', 0.7661359310150146), ('Fazal', 0.15949445962905884)]
# Max similarity: 0.064, Threshold: 0.5
# Similarities: [('Abdul', -0.08492277562618256), ('Adeen', 0.0635942667722702), ('Fazal', 0.009439121931791306)]
#
# 0: 480x640 2 faces, 6.1ms
# Speed: 2.0ms preprocess, 6.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Max similarity: 0.762, Threshold: 0.5
# Similarities: [('Abdul', 0.11663366854190826), ('Adeen', 0.7624239325523376), ('Fazal', 0.15683498978614807)]
# Max similarity: 0.306, Threshold: 0.5
# Similarities: [('Abdul', 0.11143331229686737), ('Adeen', 0.17421117424964905), ('Fazal', 0.30649465322494507)]
#
# 0: 480x640 2 faces, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Max similarity: 0.783, Threshold: 0.5
# Similarities: [('Abdul', 0.19212566316127777), ('Adeen', 0.7831295728683472), ('Fazal', 0.1494159698486328)]
# Max similarity: 0.264, Threshold: 0.5
# Similarities: [('Abdul', 0.07967327535152435), ('Adeen', 0.20922613143920898), ('Fazal', 0.2643364667892456)]
#
# 0: 480x640 2 faces, 11.8ms
# Speed: 2.0ms preprocess, 11.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Max similarity: 0.776, Threshold: 0.5
# Similarities: [('Abdul', 0.21186919737641863), ('Adeen', 0.7761547102835961), ('Fazal', 0.18624321006278965)]
# Max similarity: 0.425, Threshold: 0.5
# Similarities: [('Abdul', 0.23480378091335297), ('Adeen', 0.2887638211250305), ('Fazal', 0.4251357316970825)]
#
# 0: 480x640 2 faces, 12.0ms
# Speed: 1.6ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Max similarity: 0.763, Threshold: 0.5
# Similarities: [('Abdul', 0.17710624635219574), ('Adeen', 0.7625063061714172), ('Fazal', 0.11512213945388794)]
# Max similarity: 0.423, Threshold: 0.5
# Similarities: [('Abdul', 0.1953962328793868), ('Adeen', 0.24447961184504008), ('Fazal', 0.4229186819244224)]
#
# 0: 480x640 2 faces, 12.0ms
# Speed: 1.7ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Max similarity: 0.790, Threshold: 0.5
# Similarities: [('Abdul', 0.20696991682052612), ('Adeen', 0.7900217771530151), ('Fazal', 0.15082815289497375)]
# Max similarity: 0.432, Threshold: 0.5
# Similarities: [('Abdul', 0.2882048017856602), ('Adeen', 0.30289600474262257), ('Fazal', 0.4319738786236127)]
#
# 0: 480x640 2 faces, 11.9ms
# Speed: 1.0ms preprocess, 11.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Max similarity: 0.766, Threshold: 0.5
# Similarities: [('Abdul', 0.18748459219932556), ('Adeen', 0.7656722068786621), ('Fazal', 0.22850079834461212)]
# Max similarity: 0.444, Threshold: 0.5
# Similarities: [('Abdul', 0.2794253063544454), ('Adeen', 0.2625970683934056), ('Fazal', 0.4441959593179259)]
#
# 0: 480x640 2 faces, 11.9ms
# Speed: 2.0ms preprocess, 11.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Max similarity: 0.769, Threshold: 0.5
# Similarities: [('Abdul', 0.14884787797927856), ('Adeen', 0.768531858921051), ('Fazal', 0.2382746934890747)]
# Max similarity: 0.441, Threshold: 0.5
# Similarities: [('Abdul', 0.2202472984790802), ('Adeen', 0.24219496548175812), ('Fazal', 0.4406382739543915)]
#
# 0: 480x640 2 faces, 11.9ms
# Speed: 1.0ms preprocess, 11.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Max similarity: 0.742, Threshold: 0.5
# Similarities: [('Abdul', 0.12249324485699886), ('Adeen', 0.7418789421392131), ('Fazal', 0.24737504140287436)]
# Max similarity: 0.433, Threshold: 0.5
# Similarities: [('Abdul', 0.172148202529657), ('Adeen', 0.24389371312298147), ('Fazal', 0.43314364950992845)]
